# %%
from bing_image_downloader import downloader

# Simply pass the keyword argument without specifying it by name
downloader.download('', 
                    limit=150, 
                    output_dir='dataset', 
                    adult_filter_off=True, 
                    force_replace=False, 
                    timeout=60)
# Out:
# [%] Downloading Images to /home/vetri/Documents/Open_CV/gender_age_detection/dataset/beautiful_girls_in_the_world
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://theawesomedaily.com/wp-content/uploads/2017/04/the-most-beautiful-girl-in-the-world-15.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.wallpaperbetter.com/wallpaper/1008/755/743/most-beautiful-girl-in-the-world-2K-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://steemitimages.com/DQmbedT5crtvwFXG9ke9PnSXerWPytywoceJ42Uorvq7SPL/Most-Beautiful-Girls-Wallpapers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/59/39/77/59397761fc67d89dd448c74bce0e7061.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://s-media-cache-ak0.pinimg.com/originals/1e/bc/c4/1ebcc45f7e4cc9fa86d6bc83730f9b05.jpg
# [%] File Downloaded !
#
# ...
